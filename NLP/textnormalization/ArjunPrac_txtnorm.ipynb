# %%
import pandas as pd
import re 
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
#tsk1

# %%
stopwords = nlp.Defaults.stop_words

# %%
stopwords
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
#task2

# %%
tk = ['cries','this','lied','computing','organizing','matches']

# %%
for token in tk:
    print(token)
# Out:
# cries
# this
# lied
# computing
# organizing
# matches

# %%
import nltk

# %%
from nltk.stem import PorterStemmer

# %%
for token in tk:
    a=PorterStemmer().stem(token)
    print(a)
# Out:
# cri
# thi
# lie
# comput
# organ
# match

# %%
doc = nlp("cries this lied computing organizing matches")

# %%
for token in doc:
    print(token, token.lemma_)
# Out:
# cries cry
# this this
# lied lie
# computing computing
# organizing organize
# matches match

# %%
# use join 
tke = " ".join(tk)

# %%
doc=nlp(tke)

# %%
for i in doc:
    print(i, i.lemma_)
# Out:
# cries cry
# this this
# lied lie
# computing computing
# organizing organize
# matches match

# %%
#tsk3

# %%
dfsc = open('DS3_C2_S3_ScifiscriptsIntro_Data_Practice.txt')

# %%
txt = dfsc.read()

# %%
txt
# Out:
# 'Note from poster to Kubrick newsgroup:\n\nI found this on a bbs a while ago and I thought I\'d pass it along to all \nof you Kubrick freaks out there.\n\n02/23/89\nTranscriber\'s note:\n\nFor all you Clarke/Kubrick/2001 fans,\n\nI found the original paper copy of this screenplay a while back and felt \ncompelled to transcribe it to disk and upload it to various bulletin \nboards for the enjoyment of all.\n\nThe final movie deviates from this screenplay in a number of interesting \nways. I\'ve tried to maintain the format of the original document except \nthe number of lines per page of the original. In order to reduce the \nlength of this file I\'ve used a bar of "------" to delimit the pages as \nthere was a lot of whitespace per original screenplay page.\n'

# %%
#tokenization of text using spacy
doc1 = nlp(txt)

# %%
for token in doc1:
    print(token.text)
# Out:
# Note
# from
# poster
# to
# Kubrick
# newsgroup
# :
#
#
#
# I
# found
# this
# on
# a
# bbs
# a
# while
# ago
# and
# I
# thought
# I
# 'd
# pass
# it
# along
# to
# all
#
#
# of
# you
# Kubrick
# freaks
# out
# there
# .
#
#
#
# 02/23/89
#
#
# Transcriber
# 's
# note
# :
#
#
#
# For
# all
# you
# Clarke
# /
# Kubrick/2001
# fans
# ,
#
#
#
# I
# found
# the
# original
# paper
# copy
# of
# this
# screenplay
# a
# while
# back
# and
# felt
#
#
# compelled
# to
# transcribe
# it
# to
# disk
# and
# upload
# it
# to
# various
# bulletin
#
#
# boards
# for
# the
# enjoyment
# of
# all
# .
#
#
#
# The
# final
# movie
# deviates
# from
# this
# screenplay
# in
# a
# number
# of
# interesting
#
#
# ways
# .
# I
# 've
# tried
# to
# maintain
# the
# format
# of
# the
# original
# document
# except
#
#
# the
# number
# of
# lines
# per
# page
# of
# the
# original
# .
# In
# order
# to
# reduce
# the
#
#
# length
# of
# this
# file
# I
# 've
# used
# a
# bar
# of
# "
# ------
# "
# to
# ...

# %%
ls=[]

for i in doc1:
    if i.is_stop==False:
        ls.append(i)

# %%
ls
# Out:
# [Note,
#  poster,
#  Kubrick,
#  newsgroup,
#  :,
#
#  ,
#  found,
#  bbs,
#  ago,
#  thought,
#  pass,
#  ,
#  Kubrick,
#  freaks,
#  .,
#
#  ,
#  02/23/89,
#  ,
#  Transcriber,
#  note,
#  :,
#
#  ,
#  Clarke,
#  /,
#  Kubrick/2001,
#  fans,
#  ,,
#
#  ,
#  found,
#  original,
#  paper,
#  copy,
#  screenplay,
#  felt,
#  ,
#  compelled,
#  transcribe,
#  disk,
#  upload,
#  bulletin,
#  ,
#  boards,
#  enjoyment,
#  .,
#
#  ,
#  final,
#  movie,
#  deviates,
#  screenplay,
#  number,
#  interesting,
#  ,
#  ways,
#  .,
#  tried,
#  maintain,
#  format,
#  original,
#  document,
#  ,
#  number,
#  lines,
#  page,
#  original,
#  .,
#  order,
#  reduce,
#  ,
#  length,
#  file,
#  bar,
#  ",
#  ------,
#  ",
#  delimit,
#  pages,
#  ,
#  lot,
#  whitespace,
#  original,
#  screenplay,
#  page,
#  .,
#  ]

# %%
sentxt = "I walk a lonely road.The only one that I have ever known.Don't know where it goes. But it's home to me, and I walk alone."

# %%
#tokenization of text using spacy
doc2 = nlp(sentxt)

# %%
for token in doc2:
    print(token.text)
# Out:
# I
# walk
# a
# lonely
# road
# .
# The
# only
# one
# that
# I
# have
# ever
# known
# .
# Don't
# know
# where
# it
# goes
# .
# But
# it
# 's
# home
# to
# me
# ,
# and
# I
# walk
# alone
# .

# %%
le=[]

for i in doc2:
    if i.is_stop==False:
        le.append(i)

# %%
le
# Out:
# [walk, lonely, road, ., known, ., Don't, know, goes, ., home, ,, walk, .]

# %%
#tsk4

# %%
sen2tx = "Brayn visited his friend for a while and then went home at 10 p.m."

# %%
doc3 = nlp(sen2tx)

# %%
for word in doc3:
    print(word.text,",POS:",word.pos_,",Tag:",word.tag_)
# Out:
# Brayn ,POS: PROPN ,Tag: NNP
# visited ,POS: VERB ,Tag: VBD
# his ,POS: PRON ,Tag: PRP$
# friend ,POS: NOUN ,Tag: NN
# for ,POS: ADP ,Tag: IN
# a ,POS: DET ,Tag: DT
# while ,POS: NOUN ,Tag: NN
# and ,POS: CCONJ ,Tag: CC
# then ,POS: ADV ,Tag: RB
# went ,POS: VERB ,Tag: VBD
# home ,POS: ADV ,Tag: RB
# at ,POS: ADP ,Tag: IN
# 10 ,POS: NUM ,Tag: CD
# p.m. ,POS: NOUN ,Tag: NN

# %%
#tsk5

# %%
dfrn = open('DS3_C2_S3_Random_Data_Practice.txt')

# %%
txt2 = dfrn.read()

# %%
txt2
# Out:
# 'PADUA HIGH SCHOOL - DAY\nRevision November 12, 1997\n'

# %%
doc4 = nlp(txt2)

# %%
for word in doc4:
    print(word.text,",POS:",word.pos_,",Tag:",word.tag_)
# Out:
# PADUA ,POS: VERB ,Tag: VBD
# HIGH ,POS: ADJ ,Tag: JJ
# SCHOOL ,POS: PROPN ,Tag: NNP
# - ,POS: PUNCT ,Tag: HYPH
# DAY ,POS: PROPN ,Tag: NNP
#
#  ,POS: SPACE ,Tag: _SP
# Revision ,POS: PROPN ,Tag: NNP
# November ,POS: PROPN ,Tag: NNP
# 12 ,POS: NUM ,Tag: CD
# , ,POS: PUNCT ,Tag: ,
# 1997 ,POS: NUM ,Tag: CD
#
#  ,POS: SPACE ,Tag: _SP

# %%
for word in doc4:
    if word.pos_=='PROPN' or word.pos_=='NUM':
         print(word.text)
# Out:
# SCHOOL
# DAY
# Revision
# November
# 12
# 1997

# %%
# tsk6

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
old=nlp.Defaults.stop_words

# %%
old
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
old|={'AA','bb','CC','dd','EE'}

# %%
old
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'AA',
#  'CC',
#  'EE',
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'bb',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'dd',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
# ...

# %%
len(old)
# Out:
# 331

# %%
new=old-{'always','never','between','becomes'}

# %%
new
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'AA',
#  'CC',
#  'EE',
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'bb',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'dd',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
# ...

# %%
len(new)
# Out:
# 327

# %%
#tsk7
#removing stopwords

# %%
dfan =open('DS3_C2_S3_Sample_Data_Practice.txt')

# %%
txt3 = dfan.read()

# %%
txt3
# Out:
# "PADUA HIGH SCHOOL - DAY\nRevision November 12, 1997\nI hope dinner's ready because I only have ten minutes before Mrs. Johnson squirts out a screamer.\nHe grabs the mail and rifles through it, as he bends down to kiss Sharon on the cheek.\nMICHAEL- C'mon. I'm supposed to give you the tour. They head out of the office\nMICHAEL (continuing)- So -- which Dakota you from?\n          \n                                 \n"

# %%
doc5 = nlp(txt3)

# %%
for token in doc5:
    print(token.text)
# Out:
# PADUA
# HIGH
# SCHOOL
# -
# DAY
#
#
# Revision
# November
# 12
# ,
# 1997
#
#
# I
# hope
# dinner
# 's
# ready
# because
# I
# only
# have
# ten
# minutes
# before
# Mrs.
# Johnson
# squirts
# out
# a
# screamer
# .
#
#
# He
# grabs
# the
# mail
# and
# rifles
# through
# it
# ,
# as
# he
# bends
# down
# to
# kiss
# Sharon
# on
# the
# cheek
# .
#
#
# MICHAEL-
# C'm
# on
# .
# I
# 'm
# supposed
# to
# give
# you
# the
# tour
# .
# They
# head
# out
# of
# the
# office
#
#
# MICHAEL
# (
# continuing)-
# So
# --
# which
# Dakota
# you
# from
# ?

# %%
filtered_tokens = [token.text for token in doc5 if not token.is_stop]

# %%
filtered_text = " ".join(filtered_tokens)

# %%
print(filtered_text)
# Out:
# PADUA HIGH SCHOOL - DAY
#  Revision November 12 , 1997
#  hope dinner ready minutes Mrs. Johnson squirts screamer .
#  grabs mail rifles , bends kiss Sharon cheek .
#  MICHAEL- C'm . supposed tour . head office
#  MICHAEL ( continuing)- -- Dakota ?

# %%
len(txt3)
# Out:
# 411

# %%
len(filtered_text)
# Out:
# 290

# %%
doc6 = nlp(filtered_text)

# %%
for token in doc6:
    print(token.text,":",token.lemma_)
# Out:
# PADUA : PADUA
# HIGH : high
# SCHOOL : SCHOOL
# - : -
# DAY : DAY
#
#   :
#
# Revision : Revision
# November : November
# 12 : 12
# , : ,
# 1997 : 1997
#
#   :
#
# hope : hope
# dinner : dinner
# ready : ready
# minutes : minute
# Mrs. : Mrs.
# Johnson : Johnson
# squirts : squirt
# screamer : screamer
# . : .
#
#   :
#
# grabs : grab
# mail : mail
# rifles : rifle
# , : ,
# bends : bend
# kiss : kiss
# Sharon : Sharon
# cheek : cheek
# . : .
#
#   :
#
# MICHAEL- : michael-
# C'm : c'm
# . : .
# supposed : suppose
# tour : tour
# . : .
# head : head
# office : office
#
#   :
#
# MICHAEL : MICHAEL
# ( : (
# continuing)- : continuing)-
# -- : --
# Dakota : Dakota
# ? : ?
#
#
#
#  :

# %%
for token in doc6:
    print(token.text,":",token.pos_,",Tag:",token.tag_)
# Out:
# PADUA : VERB ,Tag: VBD
# HIGH : ADJ ,Tag: JJ
# SCHOOL : PROPN ,Tag: NNP
# - : PUNCT ,Tag: HYPH
# DAY : PROPN ,Tag: NNP
#
#   : SPACE ,Tag: _SP
# Revision : PROPN ,Tag: NNP
# November : PROPN ,Tag: NNP
# 12 : NUM ,Tag: CD
# , : PUNCT ,Tag: ,
# 1997 : NUM ,Tag: CD
#
#   : SPACE ,Tag: _SP
# hope : VERB ,Tag: VBP
# dinner : NOUN ,Tag: NN
# ready : ADJ ,Tag: JJ
# minutes : NOUN ,Tag: NNS
# Mrs. : PROPN ,Tag: NNP
# Johnson : PROPN ,Tag: NNP
# squirts : VERB ,Tag: VBZ
# screamer : NOUN ,Tag: NN
# . : PUNCT ,Tag: .
#
#   : SPACE ,Tag: _SP
# grabs : NOUN ,Tag: NNS
# mail : NOUN ,Tag: NN
# rifles : NOUN ,Tag: NNS
# , : PUNCT ,Tag: ,
# bends : NOUN ,Tag: NNS
# kiss : VERB ,Tag: VBP
# Sharon : PROPN ,Tag: NNP
# cheek : NOUN ,Tag: NN
# . : PUNCT ,Tag: .
#
#   : SPACE ,Tag: _SP
# MICHAEL- : X ,Tag: FW
# C'm : ADV ,Tag: RB
# . : PUNCT ,Tag: .
# supposed : VERB ,Tag: VBN
# tour : NOUN ,Tag: NN
# . : PUNCT ,Tag: .
# head : NOUN ,Tag: NN
# office : PROPN ,Tag: NNP
#
#   : SPACE ,Tag: _SP
# ...
